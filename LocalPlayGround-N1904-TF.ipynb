# %% [markdown]
# # Setting up a Local Play Ground (N1904-TF)
#
# ## Table of content (TOC)<a class="anchor" id="TOC"></a>
# * <a href="#bullet1">1 - Introduction</a>
# * <a href="#bullet2">2 - Loading the data</a>
# * <a href="#bullet5">5 - Version</a>

# %% [markdown]
# # 1 - Introduction <a class="anchor" id="bullet1"></a>
# ##### [Back to TOC](#TOC)
#
# Setting up the file location structure of the playground.
# See image:
#     <img src="images/PlaygroundSetup.png">
#
# Note that the variable `version` is defined as:
# > The version directory with the actual `tf` files that will be used.

# %% [markdown]
# # 2 - Loading the data<a class="anchor" id="bullet2"></a>
# ##### [Back to TOC](#TOC)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
# load the app and data from local disc
N1904 = use("app:~/text-fabric-data/github/CenterBLC/N1904/app", hoist=globals())
# Out:
# **Locating corpus resources ...**
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.1</a>, <a target="_blank" href="https://github.com/CenterBLC//blob/main/app" title="app:~/text-fabric-data/github/CenterBLC/N1904/app app">CenterBLC//app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
testQuery2 = """
% go over all sentence nodes 
sentence
      word
"""
# Execute the query
testResults2 = N1904.search(testQuery2,silent=False)
# Out:
#   0.34s 137779 results

# %%
N1904.show(testResults2,start=1,end=2,condenseType='sentence',baseTypes='phrase')
# Out:
# <p><b>sentence</b> <i>1</i>
# ...

# %%
test=MPTF.export(testResults2)

# %%
type(test)
# Out:
# NoneType

# %% [markdown]
# # Notebook and environment details<a class="anchor" id="bulletY"></a>
# ##### [Back to TOC](#TOC)
#
# <div style="float: left;">
#   <table>
#     <tr>
#       <td><strong>Author</strong></td>
#       <td>Tony Jurg</td>
#     </tr>
#     <tr>
#       <td><strong>Version</strong></td>
#       <td>0.1</td>
#     </tr>
#     <tr>
#       <td><strong>Date</strong></td>
#       <td>7 March 2025</td>
#     </tr>
#   </table>
# </div>
